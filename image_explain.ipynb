# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
api_key=os.getenv("OPEN_API_KEY")

# %%
client = OpenAI(api_key=api_key)

# %%
messages=[
    {
        "role":"user",
        "content":[
            {"type":"text", "text": "이 이미지에 대해 설명해 주세요."},
            {
                "type": "image_url",
                "image_url":{
                    "url": "https://images.unsplash.com/photo-1748989431540-434fad2e77c7?q=80&w=1974&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",
                },
            },
        ],
    }
]

response=client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
response
# Out:
# ChatCompletion(id='chatcmpl-Bhr9vN5RPfDAxWTCObPpcBNLQcdE0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지에는 두 사람이 건물 옆을 걷고 있는 모습이 담겨 있습니다. 건물에는 차량 관련 경고 표지판이 달린 가로등이 있고, 가로등과 사람의 그림자가 벽에 비추고 있습니다. 배경의 벽은 커다란 직사각형 창문이 있고, 벽 일부는 어둠과 햇빛이 교차하고 있습니다. 전체적으로 도시의 일상적인 거리 풍경을 담고 있습니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1749792147, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_a288987b44', usage=CompletionUsage(completion_tokens=105, prompt_tokens=1120, total_tokens=1225, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %% [markdown]
# -----------------------------------
# image(mine)

# %%
import base64

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
image_path="C:/Users/장동민/Desktop/KakaoTalk_20241025_214440308.jpg"

# %%
base64_image=encode_image(image_path)

# %%
print(base64_image)
# Out:
# ...

# %%
messages=[
    {
        "role":"user",
        "content":[
            {
                "type":"image_url",
                "image_url":{
                    "url":f"data:image/jpeg;base64,{base64_image}",
                },
             },
        ],
    }
]
response=client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
response.choices[0].message.content
# Out:
# 'I’m sorry, I can’t tell who this person is. However, they appear to be enjoying a sandwich in a restaurant setting. The walls have several framed photos, and there are industrial pipes visible on the ceiling.'

# %% [markdown]
# -----------------
# multi_images

# %%
test01_base64=encode_image("C:/Users/장동민/Desktop/test_image01.png")

# %%
test02_base64=encode_image("C:/Users/장동민/Desktop/test_image02.jfif")

# %%
messages=[
    {
        "role":"user",
        "content":[
            {"type":"text","text":"what is different between two pictures?"},
            {
                "type": "image_url",
                "image_url":{
                    "url":f"data:image/png;base64,{test01_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url":{
                    "url":f"data:image/jfif;base64,{test02_base64}",
                },
            },
        ],
    }
]
response=client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
response.choices[0].message.content
# Out:
# 'The two pictures are very different in their settings:\n\n1. **First Image**: \n   - Depicts a beach scene with sand and an ocean in the background.\n   - There is a star drawn in the sand.\n   - The environment is coastal.\n\n2. **Second Image**: \n   - Shows a mountainous landscape.\n   - The mountains are covered with snow, and there are clouds in the sky.\n   - The environment is a high-altitude, cold terrain.\n\nThe main differences are the environments, one being a beach and the other a mountainous region.'
